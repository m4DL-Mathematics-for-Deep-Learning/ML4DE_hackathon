# %%
#Importing necessary packages
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import pickle
import torch.nn.functional as F

# %%
torch.manual_seed(7)
np.random.seed(7)

# %%
dtype = torch.float32
np_dtype = np.float32

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(device)
# Out:
# mps

# %%
class dataset(Dataset):
  def __init__(self,x,y,device):
    self.x = torch.from_numpy(x.astype(np_dtype)).to(device)
    self.y = torch.from_numpy(y.astype(np_dtype)).to(device)
    self.length = self.x.shape[0]
 
  def __getitem__(self,idx):
    return self.x[idx],self.y[idx]
  def __len__(self):
    return self.length

# %%
import torch
import torch.nn as nn
import numpy as np

# Make sure to choose your device (e.g., "cuda" if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def train_multistep(model, trainloader, lr, weight_decay, epochs, device):
    """
    Trains the model using multi-step rollouts so that error accumulation is penalized.
    Each batch from the loader is a pair of tensors (x, y) of shape (B, 3, seq_len), where:
      - For a given sample i:
            x[i, :, 0] is the initial condition,
            y[i, :, t] is the true state at time step t+1 for t in 0 to seq_len-1.
    
    The model (with its forward performing one RK4 step) is rolled out repeatedly starting
    from the initial state, and the loss is accumulated over the full rollout.
    """
    model.to(device)
    model.train()
    
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    
    # Optionally, you can configure a learning rate scheduler here.
    # For example, a cyclic scheduler:
    scheduler = torch.optim.lr_scheduler.CyclicLR(
        optimizer, 
        base_lr=1e-3, 
        max_lr=1e-2, 
        step_size_up=10000, 
        mode='exp_range', 
        cycle_momentum=False
    )
    
    for epoch in range(1, epochs + 1):
        total_loss = 0.0
        num_batches = 0
        
        for x, y in trainloader:
            # x and y are expected to have shape (batch, 3, seq_len)
            x, y = x.to(device), y.to(device)
            
            # Reset the optimizer gradients.
            optimizer.zero_grad()
            
            # Initialize current_state from the first time step of the input sequences.
            # This is the initial condition for the rollout.
            current_state = x[:, :, 0]  # shape: (batch, 3)
            loss = 0.0
            
            # Roll out the model over the sequence.
            seq_len = x.size(2)
            for t in range(seq_len):
                # Each call to model produces one RK4 integration step.
                prediction = model(current_state)  # shape: (batch, 3)
                # Compare the prediction with the ground truth for this time step.
                # y[:, :, t] corresponds to the state at time t+1.
                loss += criterion(prediction, y[:, :, t])
                # Update current_state for the next iteration in the rollout.
                current_state = prediction
            
            # Optionally average loss over the sequence:
            loss = loss / seq_len
            
            loss.backward()
            optimizer.step()
            scheduler.step()  # Update scheduler per batch if using cyclic scheduling.
            
            total_loss += loss.item()
            num_batches += 1

        avg_loss = total_loss / num_batches
        if epoch == 1 or epoch % 5 == 0:
            print(f"Epoch [{epoch}/{epochs}] - Average Loss: {avg_loss:.6f}")

    print("Training complete.")

# %%
data_train = np.load("ks_training.npy")
data_test = np.load("ks_truth.npy")

# %%
from torch.utils.data import TensorDataset, DataLoader

def create_lorenz_dataloaders(data_train, data_test, seq_len=5, batch_size=128):
    """
    Split data into training and testing DataLoaders for a time-series-like dataset,
    where each sample is a sequence of consecutive time steps.

    Each sample consists of an input X and target Y where:
      - X[i] = data[i : i+seq_len]
      - Y[i] = data[i+1 : i+seq_len+1]
      
    The input X and the target Y are transposed to shape (D, seq_len), 
    so that overall they are tensors of shape (num_samples, D, seq_len).
    
    Args:
      data (np.array): Array of shape (T, D) containing the time-series data,
                       where T is the number of time steps and D is the feature dimension.
      train_ratio (float): Fraction of data used for training. The remainder is for testing.
      seq_len (int): Number of time steps in each sequence.
      batch_size (int): Batch size for the DataLoader.
      
    Returns:
      train_loader, test_loader: DataLoaders for training and testing.
    """
    T, D = data_train.shape  # T time steps, D features (e.g., D=3 for 3D points)
    
    # Determine split index for training (make sure the training set can support an entire sequence)
    N_train = T
    # Adjust so that we can extract windows of length seq_len+1 for training
    if N_train < seq_len + 1:
        raise ValueError("Not enough data points for the specified sequence length in the training set.")

    # --- Construct training examples ---
    # For training, we can iterate from 0 to N_train - seq_len - 1 so that X[i+seq_len] exists.
    train_x = [data_train[i : i + seq_len] for i in range(0, N_train - seq_len)]
    train_y = [data_train[i + 1 : i + seq_len + 1] for i in range(0, N_train - seq_len)]
    
    # Convert lists to numpy arrays
    # Now each sample is (seq_len, D)
    train_x = np.array(train_x)
    train_y = np.array(train_y)
    
    # Transpose each sample to have shape (D, seq_len)
    # The resulting tensor shape will be (num_train_samples, D, seq_len)
    train_x = np.transpose(train_x, (0, 2, 1))
    train_y = np.transpose(train_y, (0, 2, 1))
    
    # --- Construct testing examples ---
    
    T_test, D_test = data_test.shape  # T time steps, D features (e.g., D=3 for 3D points)
    
    # Determine split index for training (make sure the training set can support an entire sequence)
    N_test = T_test
    
    test_x = [data_test[i : i + seq_len] for i in range(0, T_test - seq_len)]
    test_y = [data_test[i + 1 : i + seq_len + 1] for i in range(0, T_test - seq_len)]
    
    test_x = np.array(test_x)
    test_y = np.array(test_y)
    
    test_x = np.transpose(test_x, (0, 2, 1))
    test_y = np.transpose(test_y, (0, 2, 1))
    
    # Convert to torch tensors
    x_train_t = torch.from_numpy(train_x).float()
    y_train_t = torch.from_numpy(train_y).float()
    x_test_t  = torch.from_numpy(test_x).float()
    y_test_t  = torch.from_numpy(test_y).float()
    
    # Build TensorDatasets and DataLoaders
    train_dataset = TensorDataset(x_train_t, y_train_t)
    test_dataset  = TensorDataset(x_test_t, y_test_t)
    
    train_loader  = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader   = DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=False)
    
    return train_loader, test_loader

train_loader, test_loader = create_lorenz_dataloaders(data_train, data_test, batch_size=32)

# %%
class network(nn.Module):
    def __init__(self,n_layers,dim,h,dt):
        super().__init__()
        
        self.dim = dim
        self.h = h
        self.lift = nn.Linear(self.dim,self.h)
        self.n_layers = n_layers
        if self.n_layers>2:
            self.linears = nn.ModuleList([
                nn.Linear(self.h,self.h)
                for _ in range(self.n_layers - 2)
            ])
        self.proj = nn.Linear(self.h,self.dim)
        self.act = nn.LeakyReLU()
        self.dt = dt
        
    def vecField(self,X):
        X = self.act(self.lift(X))
        if self.n_layers>2:
            for i in range(self.n_layers-2):
                X = self.act(self.linears[i](X))
        output = self.proj(X)
        return output
        
    def forward(self,U):
        """
        Performs one integration step using the RK4 method.
        
        Given a state U, we compute:
        
          k1 = f(U)
          k2 = f(U + 0.5 * dt * k1)
          k3 = f(U + 0.5 * dt * k2)
          k4 = f(U + dt * k3)
          
          U_next = U + dt/6 * (k1 + 2*k2 + 2*k3 + k4)
        """
        dt = self.dt
        
        # Compute the four slopes
        k1 = self.vecField(U)
        k2 = self.vecField(U + 0.5 * dt * k1)
        k3 = self.vecField(U + 0.5 * dt * k2)
        k4 = self.vecField(U + dt * k3)
        
        # Return the updated state according to the RK4 formula
        U_next = U + (dt / 6) * (k1 + 2 * k2 + 2 * k3 + k4)
        return U_next

# %%
n_layers = 3
dt = 0.01
hidden_dimension = 50
model = network(n_layers=n_layers,
                dt=dt,
                h=hidden_dimension,
                dim=2048)
model.to(device);

# %%
lr = 1e-3
weight_decay = 0
epochs = 1000
loss = train_multistep(model, train_loader, lr, weight_decay, epochs, device)
# Out:
# Epoch [1/1000] - Average Loss: 3.109068
# Epoch [5/1000] - Average Loss: 3.037431
# Epoch [10/1000] - Average Loss: 2.699460
# Epoch [15/1000] - Average Loss: 2.096581
# Epoch [20/1000] - Average Loss: 1.553244
# Epoch [25/1000] - Average Loss: 1.230600
# Epoch [30/1000] - Average Loss: 1.027972
# Epoch [35/1000] - Average Loss: 0.862175
# Epoch [40/1000] - Average Loss: 0.726307
# Epoch [45/1000] - Average Loss: 0.614211
# Epoch [50/1000] - Average Loss: 0.515720
# Epoch [55/1000] - Average Loss: 0.438432
# Epoch [60/1000] - Average Loss: 0.376826
# Epoch [65/1000] - Average Loss: 0.330803
# Epoch [70/1000] - Average Loss: 0.291530
# Epoch [75/1000] - Average Loss: 0.260747
# Epoch [80/1000] - Average Loss: 0.234641
# Epoch [85/1000] - Average Loss: 0.211789
# Epoch [90/1000] - Average Loss: 0.192813
# Epoch [95/1000] - Average Loss: 0.174892
# Epoch [100/1000] - Average Loss: 0.159734
# Epoch [105/1000] - Average Loss: 0.145966
# Epoch [110/1000] - Average Loss: 0.133391
# Epoch [115/1000] - Average Loss: 0.122192
# Epoch [120/1000] - Average Loss: 0.111504
# Epoch [125/1000] - Average Loss: 0.102161
# Epoch [130/1000] - Average Loss: 0.093640
# Epoch [135/1000] - Average Loss: 0.086513
# Epoch [140/1000] - Average Loss: 0.078964
# Epoch [145/1000] - Average Loss: 0.073359
# Epoch [150/1000] - Average Loss: 0.068420
# Epoch [155/1000] - Average Loss: 0.062977
# Epoch [160/1000] - Average Loss: 0.058509
# Epoch [165/1000] - Average Loss: 0.056734
# Epoch [170/1000] - Average Loss: 0.050809
# Epoch [175/1000] - Average Loss: 0.047421
# Epoch [180/1000] - Average Loss: 0.044696
# Epoch [185/1000] - Average Loss: 0.040816
# Epoch [190/1000] - Average Loss: 0.037477
# Epoch [195/1000] - Average Loss: 0.034842
# Epoch [200/1000] - Average Loss: 0.032058
# Epoch [205/1000] - Average Loss: 0.030279
# Epoch [210/1000] - Average Loss: 0.029588
# Epoch [215/1000] - Average Loss: 0.028277
# Epoch [220/1000] - Average Loss: 0.027210
# Epoch [225/1000] - Average Loss: 0.025215
# Epoch [230/1000] - Average Loss: 0.023621
# Epoch [235/1000] - Average Loss: 0.022849
# Epoch [240/1000] - Average Loss: 0.023485
# Epoch [245/1000] - Average Loss: 0.024860
# Epoch [250/1000] - Average Loss: 0.022904
# Epoch [255/1000] - Average Loss: 0.020719
# Epoch [260/1000] - Average Loss: 0.018395
# Epoch [265/1000] - Average Loss: 0.016831
# Epoch [270/1000] - Average Loss: 0.015847
# Epoch [275/1000] - Average Loss: 0.015307
# Epoch [280/1000] - Average Loss: 0.014757
# Epoch [285/1000] - Average Loss: 0.014289
# Epoch [290/1000] - Average Loss: 0.013858
# Epoch [295/1000] - Average Loss: 0.013495
# Epoch [300/1000] - Average Loss: 0.013371
# Epoch [305/1000] - Average Loss: 0.012781
# Epoch [310/1000] - Average Loss: 0.012631
# Epoch [315/1000] - Average Loss: 0.011989
# Epoch [320/1000] - Average Loss: 0.011850
# Epoch [325/1000] - Average Loss: 0.011776
# Epoch [330/1000] - Average Loss: 0.011728
# Epoch [335/1000] - Average Loss: 0.012657
# Epoch [340/1000] - Average Loss: 0.012530
# Epoch [345/1000] - Average Loss: 0.010783
# Epoch [350/1000] - Average Loss: 0.010228
# Epoch [355/1000] - Average Loss: 0.009786
# Epoch [360/1000] - Average Loss: 0.009455
# Epoch [365/1000] - Average Loss: 0.010811
# Epoch [370/1000] - Average Loss: 0.010058
# Epoch [375/1000] - Average Loss: 0.009400
# Epoch [380/1000] - Average Loss: 0.008666
# Epoch [385/1000] - Average Loss: 0.008366
# Epoch [390/1000] - Average Loss: 0.008722
# Epoch [395/1000] - Average Loss: 0.009073
# Epoch [400/1000] - Average Loss: 0.012274
# Epoch [405/1000] - Average Loss: 0.015601
# Epoch [410/1000] - Average Loss: 0.011775
# Epoch [415/1000] - Average Loss: 0.014559
# Epoch [420/1000] - Average Loss: 0.013012
# Epoch [425/1000] - Average Loss: 0.013109
# Epoch [430/1000] - Average Loss: 0.015859
# Epoch [435/1000] - Average Loss: 0.017636
# Epoch [440/1000] - Average Loss: 0.012317
# Epoch [445/1000] - Average Loss: 0.010821
# Epoch [450/1000] - Average Loss: 0.010470
# Epoch [455/1000] - Average Loss: 0.008127
# Epoch [460/1000] - Average Loss: 0.007654
# Epoch [465/1000] - Average Loss: 0.006616
# Epoch [470/1000] - Average Loss: 0.006060
# Epoch [475/1000] - Average Loss: 0.006175
# Epoch [480/1000] - Average Loss: 0.005676
# Epoch [485/1000] - Average Loss: 0.005575
# Epoch [490/1000] - Average Loss: 0.005378
# Epoch [495/1000] - Average Loss: 0.005120
# Epoch [500/1000] - Average Loss: 0.005062
# Epoch [505/1000] - Average Loss: 0.005061
# Epoch [510/1000] - Average Loss: 0.005186
# Epoch [515/1000] - Average Loss: 0.005765
# Epoch [520/1000] - Average Loss: 0.005320
# Epoch [525/1000] - Average Loss: 0.005356
# Epoch [530/1000] - Average Loss: 0.005521
# Epoch [535/1000] - Average Loss: 0.005786
# Epoch [540/1000] - Average Loss: 0.007031
# Epoch [545/1000] - Average Loss: 0.005691
# Epoch [550/1000] - Average Loss: 0.005208
# Epoch [555/1000] - Average Loss: 0.006129
# Epoch [560/1000] - Average Loss: 0.008055
# Epoch [565/1000] - Average Loss: 0.011033
# Epoch [570/1000] - Average Loss: 0.009507
# Epoch [575/1000] - Average Loss: 0.007307
# Epoch [580/1000] - Average Loss: 0.008601
# Epoch [585/1000] - Average Loss: 0.007468
# Epoch [590/1000] - Average Loss: 0.008391
# Epoch [595/1000] - Average Loss: 0.006625
# Epoch [600/1000] - Average Loss: 0.005558
# Epoch [605/1000] - Average Loss: 0.005021
# Epoch [610/1000] - Average Loss: 0.005912
# Epoch [615/1000] - Average Loss: 0.005282
# Epoch [620/1000] - Average Loss: 0.008755
# Epoch [625/1000] - Average Loss: 0.006710
# Epoch [630/1000] - Average Loss: 0.005149
# Epoch [635/1000] - Average Loss: 0.004430
# Epoch [640/1000] - Average Loss: 0.004287
# Epoch [645/1000] - Average Loss: 0.004744
# Epoch [650/1000] - Average Loss: 0.006303
# Epoch [655/1000] - Average Loss: 0.012363
# Epoch [660/1000] - Average Loss: 0.012208
# Epoch [665/1000] - Average Loss: 0.015708
# Epoch [670/1000] - Average Loss: 0.024480
# Epoch [675/1000] - Average Loss: 0.015495
# Epoch [680/1000] - Average Loss: 0.007099
# Epoch [685/1000] - Average Loss: 0.006790
# Epoch [690/1000] - Average Loss: 0.005906
# Epoch [695/1000] - Average Loss: 0.005091
# Epoch [700/1000] - Average Loss: 0.004441
# Epoch [705/1000] - Average Loss: 0.003363
# Epoch [710/1000] - Average Loss: 0.003237
# Epoch [715/1000] - Average Loss: 0.002937
# Epoch [720/1000] - Average Loss: 0.002925
# Epoch [725/1000] - Average Loss: 0.002852
# Epoch [730/1000] - Average Loss: 0.002768
# Epoch [735/1000] - Average Loss: 0.003110
# Epoch [740/1000] - Average Loss: 0.003163
# Epoch [745/1000] - Average Loss: 0.002975
# Epoch [750/1000] - Average Loss: 0.002829
# Epoch [755/1000] - Average Loss: 0.002755
# Epoch [760/1000] - Average Loss: 0.002844
# Epoch [765/1000] - Average Loss: 0.002903
# Epoch [770/1000] - Average Loss: 0.003124
# Epoch [775/1000] - Average Loss: 0.002977
# Epoch [780/1000] - Average Loss: 0.003157
# Epoch [785/1000] - Average Loss: 0.007618
# Epoch [790/1000] - Average Loss: 0.015879
# Epoch [795/1000] - Average Loss: 0.017707
# Epoch [800/1000] - Average Loss: 0.023836
# Epoch [805/1000] - Average Loss: 0.027275
# Epoch [810/1000] - Average Loss: 0.020130
# Epoch [815/1000] - Average Loss: 0.015596
# Epoch [820/1000] - Average Loss: 0.008658
# Epoch [825/1000] - Average Loss: 0.005616
# Epoch [830/1000] - Average Loss: 0.006526
# Epoch [835/1000] - Average Loss: 0.004450
# Epoch [840/1000] - Average Loss: 0.003411
# Epoch [845/1000] - Average Loss: 0.002931
# Epoch [850/1000] - Average Loss: 0.002731
# Epoch [855/1000] - Average Loss: 0.002398
# Epoch [860/1000] - Average Loss: 0.002463
# Epoch [865/1000] - Average Loss: 0.002516
# Epoch [870/1000] - Average Loss: 0.002457
# Epoch [875/1000] - Average Loss: 0.002315
# Epoch [880/1000] - Average Loss: 0.002321
# Epoch [885/1000] - Average Loss: 0.002601
# Epoch [890/1000] - Average Loss: 0.002211
# Epoch [895/1000] - Average Loss: 0.002492
# Epoch [900/1000] - Average Loss: 0.002328
# Epoch [905/1000] - Average Loss: 0.001955
# Epoch [910/1000] - Average Loss: 0.002058
# Epoch [915/1000] - Average Loss: 0.002346
# Epoch [920/1000] - Average Loss: 0.002769
# Epoch [925/1000] - Average Loss: 0.002407
# Epoch [930/1000] - Average Loss: 0.002571
# Epoch [935/1000] - Average Loss: 0.002227
# Epoch [940/1000] - Average Loss: 0.002535
# Epoch [945/1000] - Average Loss: 0.004472
# Epoch [950/1000] - Average Loss: 0.004221
# Epoch [955/1000] - Average Loss: 0.009690
# Epoch [960/1000] - Average Loss: 0.009048
# Epoch [965/1000] - Average Loss: 0.015331
# Epoch [970/1000] - Average Loss: 0.011413
# Epoch [975/1000] - Average Loss: 0.008669
# Epoch [980/1000] - Average Loss: 0.007872
# Epoch [985/1000] - Average Loss: 0.005493
# Epoch [990/1000] - Average Loss: 0.004652
# Epoch [995/1000] - Average Loss: 0.003348
# Epoch [1000/1000] - Average Loss: 0.003742
# Training complete.

# %%
data_test.shape
# Out:
# (100, 2048)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # required for 3d plotting

model.eval();
model.to('cpu');

# Assume model is an instance of your network (with RK4 forward) and is already defined.
# Set the model to eval mode and push it to the proper device.
device = 'cpu'
model.to(device)
model.eval()

data = np.concatenate((data_train[-1].reshape(1,2048),data_test),axis=0)
print(data.shape)

# Define the initial condition as a torch tensor (shape: (1, 3)) and move it to the device
state = torch.tensor([data[0]], device=device)

# We'll store all the states as numpy arrays for plotting.
states = []

# Append the initial state
states.append(state.cpu().detach().numpy().flatten())

# Apply the network 5000 times iteratively.
# num_steps = 300
# with torch.no_grad():  # deactivate gradients for inference
#     for _ in range(num_steps):
#         state = model(state.float())
#         states.append(state.cpu().detach().numpy().flatten())
#
# # Convert states to a numpy array (shape will be (5001, 3))
# states = np.array(states)
#
# print(f"States {states.shape}")
# # Set up a 3D plot using matplotlib.
# fig = plt.figure(figsize=(10, 8))
# ax = fig.add_subplot(111)
#
# # Plot the trajectory
# ax.imshow(states)
#
# # ax.plot(states[:, 0], states[:, 1], states[:, 2], 'k-', lw=0.5, label="Prediction")
# # ax.plot(data[:,0],data[:,1],data[:,2],'r-', lw=0.5, label="True")
# # ax.set_xlabel("X")
# # ax.set_ylabel("Y")
# # ax.set_zlabel("Z")
# # ax.set_title("Trajectory from RK4 integration (5000 steps)")
# ax.legend()
# plt.show()

# Get initial state from test data
initial_state = torch.tensor(data_test[0:1], device=device)  # Shape: (1, 3)

# Create predictions for different lengths
num_steps_list = [100, 300, 1000]
predictions = []

for num_steps in num_steps_list:
    states = []
    with torch.no_grad():  # deactivate gradients for inference
        state = initial_state.clone()  # Clone to ensure we start fresh each time
        states.append(state.cpu().detach().numpy().flatten())  # Add initial state
        for _ in range(num_steps):
            state = model(state.float())
            states.append(state.cpu().detach().numpy().flatten())
    states = np.array(states)
    predictions.append(states)

# Create figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle("Lorenz System Predictions at Different Time Horizons", fontsize=14)

# Plot each prediction with its own colorbar
for idx, (ax, states, steps) in enumerate(zip(axes, predictions, num_steps_list)):
    im = ax.imshow(states, aspect='auto', cmap='viridis')
    ax.set_title(f'{steps} Steps')
    ax.set_xlabel('State Component (x, y, z)')
    ax.set_ylabel('Time Step')

    # Add colorbar
    plt.colorbar(im, ax=ax, label='State Value')

    # Set x-ticks to show x, y, z
    ax.set_xticks([0, 1, 2])
    ax.set_xticklabels(['x', 'y', 'z'])

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# (101, 2048)

# %%
time = np.linspace(0,500,5001)

# %%
#Fixing the configuration for the plots
plt.rcParams["figure.dpi"] = 300
plt.rcParams["text.usetex"] = True
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = 10
plt.rcParams["figure.figsize"] = (4.5, 2)

# %%
data.shape, states.shape
# Out:
# ((5001, 3), (5001, 3))

# %%
time = np.linspace(0,50,5001)
plt.plot(time,states[:, 0],'k-',label="Prediction",lw=0.5)
plt.plot(time,data[:, 0],'r-',label="True",lw=0.5)
plt.ylabel(r"$x(t)$")
plt.xlabel(r"$t$")
plt.legend()
plt.show();

fig = plt.figure()
plt.plot(time,states[:, 1],'k-',label="Prediction",lw=0.5)
plt.plot(time,data[:, 1],'r-',label="True",lw=0.5)
plt.xlabel(r"$t$")
plt.ylabel(r"$y(t)$")
plt.legend()
plt.show();

fig = plt.figure()
plt.plot(time,states[:, 2],'k-',label="Prediction",lw=0.5)
plt.plot(time,data[:, 2],'r-',label="True",lw=0.5)
plt.xlabel(r"$t$")
plt.ylabel(r"$z(t)$")
plt.legend()
plt.show();

# %%
states.shape
# Out:
# (5001, 3)

# %%
states[1]
# Out:
# array([-0.85944128, -4.1105895 , 32.25924301])

# %%
data_test[0]
# Out:
# array([-0.85705945, -4.10394583, 32.26398411])

# %%
np.save('lorenz_prediction.npy', states[1:])

# %%
cc = np.load("lorenz_prediction.npy")
cc.shape
# Out:
# (5000, 3)
